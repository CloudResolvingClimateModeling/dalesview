# %%
import numpy as np
import scipy as sc
import math
from matplotlib import pyplot as plt

# %%
N =  20
x = range(2, N)
y =[]
for i in x:
    y.append(np.log(i)+ np.log(i-1))
    
plt.plot(x,y)
plt.show()

# %%
N =  20
x = range(2, N)
y =[]
for i in x:
    y.append(i+ i-1)
    
plt.plot(x,y)
plt.show()

# %%
N =  20
x = range(2, N)
y =[]
for i in x:
    y.append(i**2+ (i-1)**2)
    
plt.plot(x,y)
plt.show()
